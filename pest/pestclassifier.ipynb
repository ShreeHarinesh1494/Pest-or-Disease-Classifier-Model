# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from PIL import Image
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

import warnings
warnings.filterwarnings("ignore")

# Helper function to check for corrupt images
def check_images(directory):
    bad_images = []
    for root, _, files in os.walk(directory):
        for file in files:
            try:
                img = Image.open(os.path.join(root, file))
                img.verify()
            except (IOError, SyntaxError) as e:
                bad_images.append(os.path.join(root, file))
    return bad_images

train_dir = "D:\\pest\\plants\\train"
test_dir = "D:\\pest\\plants\\test"

bad_train_images = check_images(train_dir)
bad_test_images = check_images(test_dir)

print(f"Corrupt images in train directory: {bad_train_images}")
print(f"Corrupt images in test directory: {bad_test_images}")

# Optionally, remove corrupt images
for img in bad_train_images + bad_test_images:
    os.remove(img)

model_d = DenseNet121(weights='imagenet', include_top=False, input_shape=(256, 256, 3)) 

x = model_d.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x) 
x = Dense(512, activation='relu')(x) 
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

preds = Dense(6, activation='softmax')(x)  # Updated to 6 classes

model = Model(inputs=model_d.input, outputs=preds)

for layer in model.layers[:-8]:
    layer.trainable = False
    
for layer in model.layers[-8:]:
    layer.trainable = True

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

trdata = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
tsdata = ImageDataGenerator(rescale=1./255)

traindata = trdata.flow_from_directory(
    directory=train_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'  # Ensure this is 'categorical'
)
testdata = tsdata.flow_from_directory(
    directory=test_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'  # Ensure this is 'categorical'
)

checkpoint = ModelCheckpoint("DenseNet121.keras", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='max')

history = model.fit(traindata, validation_data=testdata, epochs=20, callbacks=[checkpoint, early])

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from PIL import Image
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input

from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

import warnings
warnings.filterwarnings("ignore")

# %%
def check_images(directory):
    bad_images = []
    for root, _, files in os.walk(directory):
        for file in files:
            try:
                img = Image.open(os.path.join(root, file))
                img.verify()
            except (IOError, SyntaxError) as e:
                bad_images.append(os.path.join(root, file))
    return bad_images

# %%
train_dir = "D:\\pest\\pest\\train"
test_dir = "D:\\pest\\pest\\test"

bad_train_images = check_images(train_dir)
bad_test_images = check_images(test_dir)

print(f"Corrupt images in train directory: {bad_train_images}")
print(f"Corrupt images in test directory: {bad_test_images}")

# Optionally, remove corrupt images
for img in bad_train_images + bad_test_images:
    os.remove(img)
# Out:
# Corrupt images in train directory: []
# Corrupt images in test directory: []

# %%
model_d = DenseNet121(weights='imagenet', include_top=False, input_shape=(256, 256, 3)) 

x = model_d.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x) 
x = Dense(512, activation='relu')(x) 
x = BatchNormalization()(x)
x = Dropout(0.5)(x)

preds = Dense(6, activation='softmax')(x)  # Updated to 6 classes

model = Model(inputs=model_d.input, outputs=preds)

# %%
for layer in model.layers[:-8]:
    layer.trainable = False
    
for layer in model.layers[-8:]:
    layer.trainable = True

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
trdata = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
tsdata = ImageDataGenerator(rescale=1./255)

traindata = trdata.flow_from_directory(
    directory=train_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'  # Ensure this is 'categorical'
)
testdata = tsdata.flow_from_directory(
    directory=test_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'  # Ensure this is 'categorical'
)
# Out:
# Found 1590 images belonging to 6 classes.
# Found 300 images belonging to 6 classes.

# %%
checkpoint = ModelCheckpoint("DenseNet121.keras", monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
early = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=20, verbose=1, mode='max')

history = model.fit(traindata, validation_data=testdata, epochs=20, callbacks=[checkpoint, early])
# Out:
# Epoch 1/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6108 - loss: 1.2176
# Epoch 1: val_accuracy improved from -inf to 0.86667, saving model to DenseNet121.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - accuracy: 0.6137 - loss: 1.2087 - val_accuracy: 0.8667 - val_loss: 0.4134
# Epoch 2/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9323 - loss: 0.1994
# Epoch 2: val_accuracy improved from 0.86667 to 0.92333, saving model to DenseNet121.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 143s 3s/step - accuracy: 0.9323 - loss: 0.1991 - val_accuracy: 0.9233 - val_loss: 0.2377
# Epoch 3/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9498 - loss: 0.1468
# Epoch 3: val_accuracy improved from 0.92333 to 0.93667, saving model to DenseNet121.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 146s 3s/step - accuracy: 0.9499 - loss: 0.1467 - val_accuracy: 0.9367 - val_loss: 0.2394
# Epoch 4/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9586 - loss: 0.1071
# Epoch 4: val_accuracy did not improve from 0.93667
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 143s 3s/step - accuracy: 0.9586 - loss: 0.1072 - val_accuracy: 0.9333 - val_loss: 0.2267
# Epoch 5/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9805 - loss: 0.0706
# Epoch 5: val_accuracy did not improve from 0.93667
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 144s 3s/step - accuracy: 0.9804 - loss: 0.0708 - val_accuracy: 0.9267 - val_loss: 0.2494
# Epoch 6/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9753 - loss: 0.0723
# Epoch 6: val_accuracy did not improve from 0.93667
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 145s 3s/step - accuracy: 0.9753 - loss: 0.0724 - val_accuracy: 0.9167 - val_loss: 0.3012
# Epoch 7/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9721 - loss: 0.0746
# Epoch 7: val_accuracy did not improve from 0.93667
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.9721 - loss: 0.0747 - val_accuracy: 0.9233 - val_loss: 0.2889
# Epoch 8/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9748 - loss: 0.0729
# Epoch 8: val_accuracy did not improve from 0.93667
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 144s 3s/step - accuracy: 0.9747 - loss: 0.0730 - val_accuracy: 0.9233 - val_loss: 0.2725
# Epoch 9/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9830 - loss: 0.0503
# Epoch 9: val_accuracy did not improve from 0.93667
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 144s 3s/step - accuracy: 0.9829 - loss: 0.0507 - val_accuracy: 0.9267 - val_loss: 0.2599
# Epoch 10/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9805 - loss: 0.0615
# Epoch 10: val_accuracy improved from 0.93667 to 0.95000, saving model to DenseNet121.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 145s 3s/step - accuracy: 0.9805 - loss: 0.0615 - val_accuracy: 0.9500 - val_loss: 0.2384
# Epoch 11/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9816 - loss: 0.0666
# Epoch 11: val_accuracy did not improve from 0.95000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 145s 3s/step - accuracy: 0.9816 - loss: 0.0663 - val_accuracy: 0.9333 - val_loss: 0.2431
# Epoch 12/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9859 - loss: 0.0393
# Epoch 12: val_accuracy did not improve from 0.95000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 145s 3s/step - accuracy: 0.9859 - loss: 0.0395 - val_accuracy: 0.9433 - val_loss: 0.1855
# Epoch 13/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9866 - loss: 0.0427
# Epoch 13: val_accuracy did not improve from 0.95000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 144s 3s/step - accuracy: 0.9865 - loss: 0.0429 - val_accuracy: 0.9500 - val_loss: 0.1907
# Epoch 14/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9878 - loss: 0.0286
# Epoch 14: val_accuracy did not improve from 0.95000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 145s 3s/step - accuracy: 0.9877 - loss: 0.0287 - val_accuracy: 0.9367 - val_loss: 0.2317
# Epoch 15/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9907 - loss: 0.0350
# Epoch 15: val_accuracy did not improve from 0.95000
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 143s 3s/step - accuracy: 0.9906 - loss: 0.0351 - val_accuracy: 0.9467 - val_loss: 0.2533
# Epoch 16/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9730 - loss: 0.0838
# Epoch 16: val_accuracy improved from 0.95000 to 0.96333, saving model to DenseNet121.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 147s 3s/step - accuracy: 0.9731 - loss: 0.0836 - val_accuracy: 0.9633 - val_loss: 0.2019
# Epoch 17/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9771 - loss: 0.0488
# Epoch 17: val_accuracy did not improve from 0.96333
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 196s 4s/step - accuracy: 0.9771 - loss: 0.0488 - val_accuracy: 0.9400 - val_loss: 0.2597
# Epoch 18/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9799 - loss: 0.0408
# Epoch 18: val_accuracy did not improve from 0.96333
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 142s 3s/step - accuracy: 0.9800 - loss: 0.0408 - val_accuracy: 0.9233 - val_loss: 0.3128
# Epoch 19/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9860 - loss: 0.0384
# Epoch 19: val_accuracy did not improve from 0.96333
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 184s 4s/step - accuracy: 0.9860 - loss: 0.0383 - val_accuracy: 0.9267 - val_loss: 0.3440
# Epoch 20/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9844 - loss: 0.0612
# Epoch 20: val_accuracy did not improve from 0.96333
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 154s 3s/step - accuracy: 0.9844 - loss: 0.0611 - val_accuracy: 0.9300 - val_loss: 0.3755

# %%
accuracy = model.evaluate(testdata)

print('Test set accuracy:', accuracy[1]*100)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.9175 - loss: 0.3886
# Test set accuracy: 93.00000071525574

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
model.save("pest_classfier_model.h5", include_optimizer=True)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
